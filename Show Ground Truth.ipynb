# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import datetime
import finplot as fplt
import glob

# %matplotlib notebook

# %%
mylist = [f for f in glob.glob("S&P500/*.csv")]
mylist
# Out:
# ['S&P500\\AAP(2010,2011).csv',
#  'S&P500\\AAP(2011,2012).csv',
#  'S&P500\\AAP(2012,2013).csv',
#  'S&P500\\AAP(2013,2014).csv',
#  'S&P500\\AAP(2014,2015).csv',
#  'S&P500\\ABMD(2010,2011).csv',
#  'S&P500\\ABMD(2011,2012).csv',
#  'S&P500\\ABMD(2012,2013).csv',
#  'S&P500\\ABMD(2013,2014).csv',
#  'S&P500\\ABMD(2014,2015).csv']

# %%
df =pd.read_csv(str(mylist[2]))
# df=df.set_index('Date')
# day = datetime.datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-0db6245426ec> in <module>
#       1 df =pd.read_csv(str(mylist[2]))
#       2 df=df.set_index('Date')
# ----> 3 day = datetime.datetime(df['Date'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'

# %%
df['buy'] = np.where(df['Signal'] == 'buy',df['Close'],np.nan)
df['sold'] = np.where(df['Signal'] == 'sell',df['Close'],np.nan)

# %%
plt.figure(figsize=(10,8))
# plt.grid()
plt.title('Buy and Sold Signal')
plt.plot(df['Close'])
plt.plot(df['buy'],color='yellow')
plt.plot(df['sold'],color='red')
plt.ylabel('Price')
plt.xlabel('Date')
# Out:
# <img src="data:image/png;base64,..." width="998.8889153504084">
# Text(0.5, 0, 'Date')
